# %% [markdown]
# # Exploring Alpha Vantage API

# %% [markdown]
# ### Imports- **Run First**

# %%
#open file with your API key
with open('here_be_monsters.txt') as file:
  quack = file.read().strip()

# %%
#import libraries
from alpha_vantage.timeseries import TimeSeries

import requests
from bs4 import BeautifulSoup

import pandas as pd
import io

# %% [markdown]
# ### How to use Alpha Vantage functions 1

# %% [markdown]
# #### Fundamental Data Functions

# %%
#pull income statement for Apple
url = 'https://www.alphavantage.co/query?function=INCOME_STATEMENT&symbol=AAPL&apikey=' + str(quack)
r = requests.get(url)
fd = BeautifulSoup(r.content)

print(fd)

# %%
#pull cash flow statement for Apple
url = 'https://www.alphavantage.co/query?function=EARNINGS&symbol=AAPL&apikey=' + str(quack)
r = requests.get(url)
fd = BeautifulSoup(r.content)

print(fd)

# %% [markdown]
# #### FX Functions

# %%
#Exchange rate from USD to JPY
url = 'https://www.alphavantage.co/query?function=CURRENCY_EXCHANGE_RATE&from_currency=USD&to_currency=AUD&apikey=' + str(quack)
r = requests.get(url)
fx = BeautifulSoup(r.content)

print(fx)
# Out:
# {
#     "Realtime Currency Exchange Rate": {
#         "1. From_Currency Code": "USD",
#         "2. From_Currency Name": "United States Dollar",
#         "3. To_Currency Code": "AUD",
#         "4. To_Currency Name": "Australian Dollar",
#         "5. Exchange Rate": "1.51762000",
#         "6. Last Refreshed": "2023-11-25 18:07:04",
#         "7. Time Zone": "UTC",
#         "8. Bid Price": "1.51757100",
#         "9. Ask Price": "1.51766100"
#     }
# }

# %%
#Exchange rate from USD to JPY with daily frequency
url = 'https://www.alphavantage.co/query?function=FX_DAILY&from_symbol=USD&to_symbol=JPY&apikey=' + str(quack)
r = requests.get(url)
fx = BeautifulSoup(r.content)

print(fx)
# Out:
# {
#     "Meta Data": {
#         "1. Information": "Forex Daily Prices (open, high, low, close)",
#         "2. From Symbol": "USD",
#         "3. To Symbol": "JPY",
#         "4. Output Size": "Compact",
#         "5. Last Refreshed": "2023-11-24 21:55:00",
#         "6. Time Zone": "UTC"
#     },
#     "Time Series FX (Daily)": {
#         "2023-11-24": {
#             "1. open": "149.61900",
#             "2. high": "149.70900",
#             "3. low": "149.19200",
#             "4. close": "149.39600"
#         },
#         "2023-11-23": {
#             "1. open": "149.52400",
#             "2. high": "149.69100",
#             "3. low": "148.88300",
#             "4. close": "149.56100"
#         },
#         "2023-11-22": {
#             "1. open": "148.37300",
#             "2. high": "149.74800",
#             "3. low": "148.01300",
#             "4. close": "149.53300"
#         },
#         "2023-11-21": {
#             "1. open": "148.35000",
# ...
